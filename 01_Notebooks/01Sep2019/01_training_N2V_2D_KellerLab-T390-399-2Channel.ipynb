# %% [markdown]
# # Noise2Void - 2D Example for time points between 390 and 399
#
# Here, the volumetric images from camera CM02 have been flipped and translated. Then the two images are considered as two channels

# %%
# We import all our dependencies.
from n2v.models import N2VConfig, N2V
import numpy as np
from csbdeep.utils import plot_history
from n2v.utils.n2v_utils import manipulate_val_data
from n2v.internals.N2V_DataGenerator import N2V_DataGenerator
from matplotlib import pyplot as plt
import urllib
import os
import zipfile
import glob
from tifffile import imread
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Training Data Preparation

# %% [markdown]
# ## Load images from CM02

# %%
datagen = N2V_DataGenerator()

# %%
filenames = glob.glob("/home/lalit/Desktop/03_Datasets/KellerLab/Data/CM02_flipped/*.tif")
filenames.sort()
imgs = [imread(img).astype('float64') for img in filenames]

print(len(imgs))
print("Typical shape:",  imgs[0].shape)
print("Typical datatype:", imgs[0].dtype)
# Out:
# 10
# Typical shape: (70, 896, 576)
# Typical datatype: float64

# %% [markdown]
# ## Take only the last 35  z-slices as input from CM02

# %%
X_CM02=[]
for i in range(len(imgs)):
    temp=imgs[i][-35:, ...]
    X_CM02.append(temp)
print(X_CM02[5].shape)
# Out:
# (35, 896, 576)

# %% [markdown]
# ## Take only the first 35 z-slices as output from CM02

# %%
Y_CM02=[]
for i in range(len(imgs)):
    temp=imgs[i][:35, ...]
    Y_CM02.append(temp)
print(Y_CM02[5].shape)
# Out:
# (35, 896, 576)

# %% [markdown]
# ## Load images from CM03

# %%
filenames = glob.glob("/home/lalit/Desktop/03_Datasets/KellerLab/Data/CM03/*.tif")
filenames.sort()
imgs = [imread(img).astype('float64') for img in filenames]

print("Typical shape:",  imgs[0].shape)
print("Typical datatype:", imgs[0].dtype)
# Out:
# Typical shape: (70, 896, 576)
# Typical datatype: float64

# %% [markdown]
# ## Take only the first 35 z-slices from CM03 as input

# %%
X_CM03=[]
for i in range(len(imgs)):
    temp=imgs[i][:35, ...]
    X_CM03.append(temp)
print(X_CM03[5].shape)
# Out:
# (35, 896, 576)

# %% [markdown]
# ## Take only the last 35 z-slices from CM03 as output

# %%
Y_CM03=[]
for i in range(len(imgs)):
    temp=imgs[i][-35:, ...]
    Y_CM03.append(temp)
print(Y_CM03[5].shape)
# Out:
# (35, 896, 576)

# %% [markdown]
# ## Combine X_CM02 and X_CM03

# %%
imgsX=X_CM02+X_CM03
print(len(imgsX))
print(imgsX[5].shape)
# Out:
# 20
# (35, 896, 576)

# %%
imgsY=Y_CM03+Y_CM02
print(len(imgsY))
print(imgsY[5].shape)
# Out:
# 20
# (35, 896, 576)

# %% [markdown]
# ## Combine imgsX and imgsY as two channels

# %%
imgs=[]
for i in range(len(imgsX)):
    combined=np.empty([imgsX[0].shape[0], imgsX[0].shape[1], imgsX[0].shape[2], 2])
    combined[..., 0]=imgsX[i]
    combined[..., 1]=imgsY[i]
    imgs.append(combined)
print(len(imgs))
print(imgs[5].shape)
# Out:
# 20
# (35, 896, 576, 2)

# %% [markdown]
# ## Visualize the images

# %%
vmin=np.min(imgs[6][20,...,0])
vmax=np.max(imgs[6][20,..., 0])
plt.figure(figsize=(30,20))
plt.subplot(1,2,1)
plt.imshow(imgs[6][20,..., 0], cmap='magma', vmin=vmin, vmax=vmax)
plt.subplot(1,2,2)
plt.imshow(imgs[6][20,..., 1], cmap='magma', vmin=vmin, vmax=vmax)
plt.show()

# %% [markdown]
# ## Since there is an artificial margin in the input and the output, we chop away the first and last 60 in the x dimension and in the y dimension

# %%
for i in range(len(imgs)):
    imgs[i]=imgs[i][:, 60:-60, 60:-60, :]
print(len(imgs))
print(imgs[5].shape)
# Out:
# 20
# (35, 776, 456, 2)

# %% [markdown]
# ## Visualize the images again

# %%
vmin=np.min(imgs[6][20,...,0])
vmax=np.max(imgs[6][20,..., 0])
plt.figure(figsize=(30,20))
plt.subplot(1,2,1)
plt.imshow(imgs[6][20,..., 0], cmap='magma', vmin=vmin, vmax=vmax)
plt.subplot(1,2,2)
plt.imshow(imgs[6][20,..., 1], cmap='magma', vmin=vmin, vmax=vmax)
plt.show()

# %% [markdown]
# ## Prepare train and validation data

# %%
# I assign the last image to validation set and the remaining to training
imgstrain=imgs[:-1]
imgsvalid=imgs[-1:]
print(len(imgstrain))
print(len(imgsvalid))
print(imgstrain[5].shape)
print(imgsvalid[0].shape)
# Out:
# 19
# 1
# (35, 776, 456, 2)
# (35, 776, 456, 2)

# %% [markdown]
# ## Augment is False (otherwise it takes too long)

# %%
# We will use the first image to extract training patches and store them in 'X'
X = datagen.generate_patches_from_list(imgstrain, shape=(96, 96), augment=False)

# We will use the second image to extract validation patches.
X_val = datagen.generate_patches_from_list(imgsvalid, shape=(96, 96), augment=False)


print(X.shape)
print(X_val.shape)


# Patches are created so they do not overlap.
# (Note: this is not the case if you specify a number of patches. See the docstring for details!)
# Non-overlapping patches would also allow us to split them into a training and validation set 
# per image. This might be an interesting alternative to the split we performed above.
# Out:
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# Generated patches: (1120, 96, 96, 2)
# (21280, 96, 96, 2)
# (1120, 96, 96, 2)

# %%
print("Datatype is:", X[0, ..., 0].dtype)
print("Datatype is:", X[0, ..., 1].dtype)
# Out:
# Datatype is: float64
# Datatype is: float64

# %%
# Let's look at one of our training and validation patches.
plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.imshow(X[48, ...,0], cmap='magma')
plt.title('Training Patch: CH0 ');
plt.subplot(2,2,2)
plt.imshow(X[48, ...,1], cmap='magma')
plt.title('Training Patch: CH1');
plt.subplot(2,2,3)
plt.imshow(X_val[20,...,0], cmap='magma')
plt.title('Validation Patch: CH0');
plt.subplot(2,2,4)
plt.imshow(X_val[20,...,1], cmap='magma')
plt.title('Validation Patch: CH1');

# %% [markdown]
# # Configure

# %% [markdown]
# Noise2Void comes with a special config-object, where we store network-architecture and training specific parameters. See the docstring of the <code>N2VConfig</code> constructor for a description of all parameters.
#
# When creating the config-object, we provide the training data <code>X</code>. From <code>X</code> we extract <code>mean</code> and <code>std</code> that will be used to normalize all data before it is processed by the network. We also extract the dimensionality and number of channels from <code>X</code>.
#
# Compared to supervised training (i.e. traditional CARE), we recommend to use N2V with an increased <code>train_batch_size</code> and <code>batch_norm</code>.
# To keep the network from learning the identity we have to manipulate the input pixels during training. For this we have the parameter <code>n2v_manipulator</code> with default value <code>'uniform_withCP'</code>. Most pixel manipulators will compute the replacement value based on a neighborhood. With <code>n2v_neighborhood_radius</code> we can control its size.
#
# Other pixel manipulators:
# * normal_withoutCP: samples the neighborhood according to a normal gaussian distribution, but without the center pixel
# * normal_additive: adds a random number to the original pixel value. The random number is sampled from a gaussian distribution with zero-mean and sigma = <code>n2v_neighborhood_radius</code>
# * normal_fitted: uses a random value from a gaussian normal distribution with mean equal to the mean of the neighborhood and standard deviation equal to the standard deviation of the neighborhood.
# * identity: performs no pixel manipulation
#
# For faster training multiple pixels per input patch can be manipulated. In our experiments we manipulated about 1.6% of the input pixels per patch. For a patch size of 64 by 64 pixels this corresponds to about 64 pixels. This fraction can be tuned via <code>n2v_perc_pix</code>.
#
# For Noise2Void training it is possible to pass arbitrarily large patches to the training method. From these patches random subpatches of size <code>n2v_patch_shape</code> are extracted during training. Default patch shape is set to (64, 64).

# %% [markdown]
# <font color='red'>Warning:</font> to make this example notebook execute faster, we have set <code>train_epochs</code> to only 10 and <code>train_steps_per_epoch</code> to only 10. <br>For better results we suggest values of 100, and a few dozen, respectively.

# %%
# You can increase "train_steps_per_epoch" to get even better results at the price of longer computation. 
config = N2VConfig(X, unet_kern_size=3, 
                   unet_n_first=64, unet_n_depth=3, train_steps_per_epoch=40, train_epochs=50, train_loss='mse', 
                   batch_norm=True, train_batch_size=128, n2v_perc_pix=5, n2v_patch_shape=(64, 64), 
                   n2v_manipulator='uniform_withCP', n2v_neighborhood_radius=5)

# Let's look at the parameters stored in the config-object.
vars(config)
# Out:
# {'mean': '122.3183972300543',
#  'std': '49.980508151106385',
#  'n_dim': 2,
#  'axes': 'YXC',
#  'n_channel_in': 2,
#  'n_channel_out': 2,
#  'unet_residual': False,
#  'unet_n_depth': 3,
#  'unet_kern_size': 3,
#  'unet_n_first': 64,
#  'unet_last_activation': 'linear',
#  'unet_input_shape': (None, None, 2),
#  'train_loss': 'mse',
#  'train_epochs': 50,
#  'train_steps_per_epoch': 40,
#  'train_learning_rate': 0.0004,
#  'train_batch_size': 128,
#  'train_tensorboard': True,
#  'train_checkpoint': 'weights_best.h5',
#  'train_reduce_lr': {'factor': 0.5, 'patience': 10},
#  'batch_norm': True,
#  'n2v_perc_pix': 5,
#  'n2v_patch_shape': (64, 64),
#  'n2v_manipulator': 'uniform_withCP',
#  'n2v_neighborhood_radius': 5}

# %%
# a name used to identify the model
model_name = 'n2v_2D_kellerLab_T390-399_2Channels'
# the base directory in which our model will live
basedir = 'models'
# We are now creating our network model.
model = N2V(config, model_name, basedir=basedir)

# %% [markdown]
# # Training
#
# Training the model will likely take some time. We recommend to monitor the progress with TensorBoard, which allows you to inspect the losses during training. Furthermore, you can look at the predictions for some of the validation images, which can be helpful to recognize problems early on.
#
# You can start TensorBoard in a terminal from the current working directory with tensorboard --logdir=. Then connect to http://localhost:6006/ with your browser.

# %%
# We are ready to start training now.
history = model.train(X, X_val)
# Out:
# Epoch 1/50
# 40/40 [==============================] - 500s 13s/step - loss: 0.1411 - n2v_mse: 0.1411 - n2v_abs: 0.1803 - val_loss: 0.0585 - val_n2v_mse: 0.0585 - val_n2v_abs: 0.1343
# Epoch 2/50
# 40/40 [==============================] - 474s 12s/step - loss: 0.0420 - n2v_mse: 0.0420 - n2v_abs: 0.1135 - val_loss: 0.0504 - val_n2v_mse: 0.0504 - val_n2v_abs: 0.1065
# Epoch 3/50
# 40/40 [==============================] - 487s 12s/step - loss: 0.0408 - n2v_mse: 0.0408 - n2v_abs: 0.1109 - val_loss: 0.0276 - val_n2v_mse: 0.0276 - val_n2v_abs: 0.1201
# Epoch 4/50
# 40/40 [==============================] - 488s 12s/step - loss: 0.0362 - n2v_mse: 0.0362 - n2v_abs: 0.1051 - val_loss: 0.0373 - val_n2v_mse: 0.0373 - val_n2v_abs: 0.1029
# Epoch 5/50
# 40/40 [==============================] - 506s 13s/step - loss: 0.0408 - n2v_mse: 0.0408 - n2v_abs: 0.1093 - val_loss: 0.0431 - val_n2v_mse: 0.0431 - val_n2v_abs: 0.1022
# Epoch 6/50
# 40/40 [==============================] - 495s 12s/step - loss: 0.0436 - n2v_mse: 0.0436 - n2v_abs: 0.1100 - val_loss: 0.0747 - val_n2v_mse: 0.0747 - val_n2v_abs: 0.1185
# Epoch 7/50
# 40/40 [==============================] - 492s 12s/step - loss: 0.0394 - n2v_mse: 0.0394 - n2v_abs: 0.1060 - val_loss: 0.0366 - val_n2v_mse: 0.0366 - val_n2v_abs: 0.1274
# Epoch 8/50
# 40/40 [==============================] - 494s 12s/step - loss: 0.0302 - n2v_mse: 0.0302 - n2v_abs: 0.0920 - val_loss: 0.0293 - val_n2v_mse: 0.0293 - val_n2v_abs: 0.1115
# Epoch 9/50
# 40/40 [==============================] - 491s 12s/step - loss: 0.0319 - n2v_mse: 0.0319 - n2v_abs: 0.0979 - val_loss: 0.0320 - val_n2v_mse: 0.0320 - val_n2v_abs: 0.0961
# Epoch 10/50
# 40/40 [==============================] - 491s 12s/step - loss: 0.0367 - n2v_mse: 0.0367 - n2v_abs: 0.1015 - val_loss: 0.0167 - val_n2v_mse: 0.0167 - val_n2v_abs: 0.0737
# Epoch 11/50
# 40/40 [==============================] - 490s 12s/step - loss: 0.0346 - n2v_mse: 0.0346 - n2v_abs: 0.0987 - val_loss: 0.0179 - val_n2v_mse: 0.0179 - val_n2v_abs: 0.0768
# Epoch 12/50
# 40/40 [==============================] - 490s 12s/step - loss: 0.0366 - n2v_mse: 0.0366 - n2v_abs: 0.1015 - val_loss: 0.0303 - val_n2v_mse: 0.0303 - val_n2v_abs: 0.1201
# Epoch 13/50
# 40/40 [==============================] - 495s 12s/step - loss: 0.0350 - n2v_mse: 0.0350 - n2v_abs: 0.0972 - val_loss: 0.0160 - val_n2v_mse: 0.0160 - val_n2v_abs: 0.0803
# Epoch 14/50
# 40/40 [==============================] - 488s 12s/step - loss: 0.0311 - n2v_mse: 0.0311 - n2v_abs: 0.0966 - val_loss: 0.0240 - val_n2v_mse: 0.0240 - val_n2v_abs: 0.0785
# Epoch 15/50
# 40/40 [==============================] - 489s 12s/step - loss: 0.0348 - n2v_mse: 0.0348 - n2v_abs: 0.0994 - val_loss: 0.0248 - val_n2v_mse: 0.0248 - val_n2v_abs: 0.0899
# Epoch 16/50
# 40/40 [==============================] - 480s 12s/step - loss: 0.0331 - n2v_mse: 0.0331 - n2v_abs: 0.0981 - val_loss: 0.0254 - val_n2v_mse: 0.0254 - val_n2v_abs: 0.0826
# Epoch 17/50
# 40/40 [==============================] - 493s 12s/step - loss: 0.0354 - n2v_mse: 0.0354 - n2v_abs: 0.1008 - val_loss: 0.0230 - val_n2v_mse: 0.0230 - val_n2v_abs: 0.0790
# Epoch 18/50
# 40/40 [==============================] - 490s 12s/step - loss: 0.0301 - n2v_mse: 0.0301 - n2v_abs: 0.0955 - val_loss: 0.0264 - val_n2v_mse: 0.0264 - val_n2v_abs: 0.1172
# Epoch 19/50
# 40/40 [==============================] - 490s 12s/step - loss: 0.0330 - n2v_mse: 0.0330 - n2v_abs: 0.0968 - val_loss: 0.0225 - val_n2v_mse: 0.0225 - val_n2v_abs: 0.1056
# Epoch 20/50
# 40/40 [==============================] - 480s 12s/step - loss: 0.0328 - n2v_mse: 0.0328 - n2v_abs: 0.0989 - val_loss: 0.0175 - val_n2v_mse: 0.0175 - val_n2v_abs: 0.0767
# Epoch 21/50
# 40/40 [==============================] - 495s 12s/step - loss: 0.0305 - n2v_mse: 0.0305 - n2v_abs: 0.0930 - val_loss: 0.0160 - val_n2v_mse: 0.0160 - val_n2v_abs: 0.0760
# Epoch 22/50
# 40/40 [==============================] - 480s 12s/step - loss: 0.0341 - n2v_mse: 0.0341 - n2v_abs: 0.1004 - val_loss: 0.0314 - val_n2v_mse: 0.0314 - val_n2v_abs: 0.0973
# Epoch 23/50
# 40/40 [==============================] - 492s 12s/step - loss: 0.0262 - n2v_mse: 0.0262 - n2v_abs: 0.0894 - val_loss: 0.0174 - val_n2v_mse: 0.0174 - val_n2v_abs: 0.0739
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# Epoch 24/50
# 40/40 [==============================] - 491s 12s/step - loss: 0.0279 - n2v_mse: 0.0279 - n2v_abs: 0.0919 - val_loss: 0.0150 - val_n2v_mse: 0.0150 - val_n2v_abs: 0.0740
# Epoch 25/50
# 40/40 [==============================] - 493s 12s/step - loss: 0.0303 - n2v_mse: 0.0303 - n2v_abs: 0.0927 - val_loss: 0.0144 - val_n2v_mse: 0.0144 - val_n2v_abs: 0.0710
# Epoch 26/50
# 40/40 [==============================] - 490s 12s/step - loss: 0.0300 - n2v_mse: 0.0300 - n2v_abs: 0.0916 - val_loss: 0.0142 - val_n2v_mse: 0.0142 - val_n2v_abs: 0.0680
# Epoch 27/50
# 40/40 [==============================] - 480s 12s/step - loss: 0.0315 - n2v_mse: 0.0315 - n2v_abs: 0.0980 - val_loss: 0.0133 - val_n2v_mse: 0.0133 - val_n2v_abs: 0.0669
# Epoch 28/50
# 40/40 [==============================] - 488s 12s/step - loss: 0.0279 - n2v_mse: 0.0279 - n2v_abs: 0.0899 - val_loss: 0.0128 - val_n2v_mse: 0.0128 - val_n2v_abs: 0.0655
# Epoch 29/50
# 40/40 [==============================] - 489s 12s/step - loss: 0.0291 - n2v_mse: 0.0291 - n2v_abs: 0.0934 - val_loss: 0.0141 - val_n2v_mse: 0.0141 - val_n2v_abs: 0.0699
# Epoch 30/50
# 40/40 [==============================] - 491s 12s/step - loss: 0.0260 - n2v_mse: 0.0260 - n2v_abs: 0.0887 - val_loss: 0.0140 - val_n2v_mse: 0.0140 - val_n2v_abs: 0.0710
# Epoch 31/50
# 40/40 [==============================] - 488s 12s/step - loss: 0.0300 - n2v_mse: 0.0300 - n2v_abs: 0.0912 - val_loss: 0.0132 - val_n2v_mse: 0.0132 - val_n2v_abs: 0.0664
# Epoch 32/50
# 40/40 [==============================] - 488s 12s/step - loss: 0.0301 - n2v_mse: 0.0301 - n2v_abs: 0.0935 - val_loss: 0.0139 - val_n2v_mse: 0.0139 - val_n2v_abs: 0.0710
# Epoch 33/50
# 40/40 [==============================] - 490s 12s/step - loss: 0.0295 - n2v_mse: 0.0295 - n2v_abs: 0.0915 - val_loss: 0.0161 - val_n2v_mse: 0.0161 - val_n2v_abs: 0.0712
# Epoch 34/50
# 40/40 [==============================] - 512s 13s/step - loss: 0.0313 - n2v_mse: 0.0313 - n2v_abs: 0.0928 - val_loss: 0.0228 - val_n2v_mse: 0.0228 - val_n2v_abs: 0.0875
# Epoch 35/50
# 40/40 [==============================] - 558s 14s/step - loss: 0.0367 - n2v_mse: 0.0367 - n2v_abs: 0.0991 - val_loss: 0.0150 - val_n2v_mse: 0.0150 - val_n2v_abs: 0.0714
# Epoch 36/50
# 40/40 [==============================] - 490s 12s/step - loss: 0.0267 - n2v_mse: 0.0267 - n2v_abs: 0.0888 - val_loss: 0.0185 - val_n2v_mse: 0.0185 - val_n2v_abs: 0.0788
# Epoch 37/50
# 40/40 [==============================] - 499s 12s/step - loss: 0.0274 - n2v_mse: 0.0274 - n2v_abs: 0.0893 - val_loss: 0.0138 - val_n2v_mse: 0.0138 - val_n2v_abs: 0.0693
# Epoch 38/50
# 40/40 [==============================] - 502s 13s/step - loss: 0.0266 - n2v_mse: 0.0266 - n2v_abs: 0.0871 - val_loss: 0.0142 - val_n2v_mse: 0.0142 - val_n2v_abs: 0.0688
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 39/50
# 40/40 [==============================] - 499s 12s/step - loss: 0.0252 - n2v_mse: 0.0252 - n2v_abs: 0.0860 - val_loss: 0.0130 - val_n2v_mse: 0.0130 - val_n2v_abs: 0.0664
# Epoch 40/50
# 40/40 [==============================] - 487s 12s/step - loss: 0.0248 - n2v_mse: 0.0248 - n2v_abs: 0.0871 - val_loss: 0.0131 - val_n2v_mse: 0.0131 - val_n2v_abs: 0.0685
# Epoch 41/50
# 40/40 [==============================] - 495s 12s/step - loss: 0.0262 - n2v_mse: 0.0262 - n2v_abs: 0.0848 - val_loss: 0.0148 - val_n2v_mse: 0.0148 - val_n2v_abs: 0.0744
# Epoch 42/50
# 40/40 [==============================] - 505s 13s/step - loss: 0.0271 - n2v_mse: 0.0271 - n2v_abs: 0.0865 - val_loss: 0.0128 - val_n2v_mse: 0.0128 - val_n2v_abs: 0.0661
# Epoch 43/50
# 40/40 [==============================] - 504s 13s/step - loss: 0.0289 - n2v_mse: 0.0289 - n2v_abs: 0.0877 - val_loss: 0.0138 - val_n2v_mse: 0.0138 - val_n2v_abs: 0.0701
# Epoch 44/50
# 40/40 [==============================] - 502s 13s/step - loss: 0.0283 - n2v_mse: 0.0283 - n2v_abs: 0.0895 - val_loss: 0.0136 - val_n2v_mse: 0.0136 - val_n2v_abs: 0.0669
# Epoch 45/50
# 40/40 [==============================] - 493s 12s/step - loss: 0.0256 - n2v_mse: 0.0256 - n2v_abs: 0.0841 - val_loss: 0.0126 - val_n2v_mse: 0.0126 - val_n2v_abs: 0.0659
# Epoch 46/50
# 40/40 [==============================] - 492s 12s/step - loss: 0.0282 - n2v_mse: 0.0282 - n2v_abs: 0.0871 - val_loss: 0.0131 - val_n2v_mse: 0.0131 - val_n2v_abs: 0.0687
# Epoch 47/50
# 40/40 [==============================] - 505s 13s/step - loss: 0.0251 - n2v_mse: 0.0251 - n2v_abs: 0.0853 - val_loss: 0.0147 - val_n2v_mse: 0.0147 - val_n2v_abs: 0.0760
# Epoch 48/50
# 40/40 [==============================] - 496s 12s/step - loss: 0.0226 - n2v_mse: 0.0226 - n2v_abs: 0.0824 - val_loss: 0.0140 - val_n2v_mse: 0.0140 - val_n2v_abs: 0.0681
# Epoch 49/50
# 40/40 [==============================] - 493s 12s/step - loss: 0.0254 - n2v_mse: 0.0254 - n2v_abs: 0.0861 - val_loss: 0.0127 - val_n2v_mse: 0.0127 - val_n2v_abs: 0.0657
# Epoch 50/50
# 40/40 [==============================] - 509s 13s/step - loss: 0.0246 - n2v_mse: 0.0246 - n2v_abs: 0.0850 - val_loss: 0.0135 - val_n2v_mse: 0.0135 - val_n2v_abs: 0.0715
#
# Loading network weights from 'weights_best.h5'.

# %% [markdown]
# ### After training, lets plot training and validation loss.

# %%
print(sorted(list(history.history.keys())))
plt.figure(figsize=(16,5))
plot_history(history,['loss','val_loss']);
# Out:
# ['loss', 'lr', 'n2v_abs', 'n2v_mse', 'val_loss', 'val_n2v_abs', 'val_n2v_mse']

# %% [markdown]
# ## Export Model to be Used with CSBDeep Fiji Plugins and KNIME Workflows
# See https://github.com/CSBDeep/CSBDeep_website/wiki/Your-Model-in-Fiji for details.

# %%
#model.export_TF()
