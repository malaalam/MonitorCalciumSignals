# %% [markdown]
# # Care - 2D Example for time points between 390 and 399
#
# Here, the volumetric images from camera CM02 have been flipped and translated. Next, the CM02 images have been registered pixel-wise. Q1
# ## CM02: Q0_o, Q1_o, Q2_o, Q3_o, Q4_o, Q4_i, Q3_i, Q2_i, Q1_i, Q0_i
# ## CM03: Q0_i, Q1_i, Q2_i, Q3_i, Q4_i, Q4_o, Q3_o, Q2_o, Q1_o, Q0_o

# %%
# We import all our dependencies.
from n2v.models import N2V
import numpy as np
from matplotlib import pyplot as plt
from tifffile import imread, imwrite
from n2v.internals.N2V_DataGenerator import N2V_DataGenerator
from csbdeep.io import save_tiff_imagej_compatible
from csbdeep.models import CARE
import glob
import copy
# Out:
# Using TensorFlow backend.

# %%
quality='Q1/'

# %%
# A previously trained model is loaded by creating a new Care object without providing a 'config'.  
model = CARE(config=None, name='care_2D_kellerlab_with_normalization_with_HandRegistration_float64_Q1_ne_300_es_250', basedir='models')
# Out:
# Loading network weights from 'weights_best.h5'.

# %% [markdown]
# ## Load images from CM02.

# %%
filenames = glob.glob("/home/lalit/Desktop/03_Datasets/KellerLab/Data/CM02_flipped/*.tif")
filenames.sort()
imgs = [imread(img).astype('float64') for img in filenames]

print(len(imgs))
print(imgs[0].shape)
# Out:
# 10
# (70, 896, 576)

# %% [markdown]
# ## Take only the  -14:-7  z-slices as input from CM02

# %%
X_CM02=[]
for i in range(len(imgs)):
    temp=imgs[i][-14:-7, ...]
    X_CM02.append(temp)
print(X_CM02[5].shape)
# Out:
# (7, 896, 576)

# %% [markdown]
# ## Take only the 7:14 z-slices as output from CM02

# %%
Y_CM02=[]
for i in range(len(imgs)):
    temp=imgs[i][7:14, ...]
    Y_CM02.append(temp)
print(Y_CM02[5].shape)
# Out:
# (7, 896, 576)

# %% [markdown]
# ## Load images from CM03

# %%
filenames = glob.glob("/home/lalit/Desktop/03_Datasets/KellerLab/Data/CM03/*.tif")
filenames.sort()
imgs = [imread(img).astype('float64') for img in filenames]

print("Typical shape:",  imgs[0].shape)
print("Typical datatype:", imgs[0].dtype)
# Out:
# Typical shape: (70, 896, 576)
# Typical datatype: float64

# %% [markdown]
# ## Take only the 7:14 z-slices from CM03 as input

# %%
X_CM03=[]
for i in range(len(imgs)):
    temp=imgs[i][7:14, ...]
    X_CM03.append(temp)
print(X_CM03[5].shape)
# Out:
# (7, 896, 576)

# %% [markdown]
# ## Take only the -14:-7 z-slices from CM03 as output

# %%
Y_CM03=[]
for i in range(len(imgs)):
    temp=imgs[i][-14:-7, ...]
    Y_CM03.append(temp)
print(Y_CM03[5].shape)
# Out:
# (7, 896, 576)

# %% [markdown]
# ## Combine X_CM02 and X_CM03

# %%
input_train=X_CM02+X_CM03
print(len(input_train))
print(input_train[5].shape)
# Out:
# 20
# (7, 896, 576)

# %%
imgsY=Y_CM03+Y_CM02
print(len(imgsY))
print(imgsY[5].shape)
# Out:
# 20
# (7, 896, 576)

# %% [markdown]
# ## At this point, we chop off the first and last 60 pixels from the X-dimension and Y-dimension and then normalize, in order to train subsequently

# %%
input_train_chopped=[]
for i in range(len(input_train)):
    input_train_chopped.append(input_train[i][:, 60:-60, 60:-60])

# %% [markdown]
# ## Copy the mean and std from the training notebooks

# %%
mean=np.array(109.82844187627575).astype('float64')
std=np.array(21.346801061957).astype('float64')

# %%
input_train_chopped_normalized=copy.deepcopy(input_train_chopped)
for i in range(len(input_train_chopped_normalized)):
    input_train_chopped_normalized[i]=(input_train_chopped[i]-mean)/std

# %%
pred_train=copy.deepcopy(input_train_chopped_normalized)
for i in range(len(input_train_chopped_normalized)):
    for j in range(input_train_chopped_normalized[i].shape[0]):
        img=input_train_chopped_normalized[i][j, ..., np.newaxis]
        result_image=model.predict(img, axes='YXC', n_tiles=(4,4,1), normalizer= None)
        pred_train[i][j, ..., np.newaxis]=result_image
# Out:
# 100%|██████████| 16/16 [00:03<00:00,  4.62it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.94it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.64it/s]
# 100%|██████████| 16/16 [00:00<00:00, 35.57it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.16it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.40it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.75it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.81it/s]
# 100%|██████████| 16/16 [00:00<00:00, 35.34it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.15it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.07it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.47it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.15it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.57it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.93it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.16it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.59it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.47it/s]
# 100%|██████████| 16/16 [00:00<00:00, 35.61it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.76it/s]
# 100%|██████████| 16/16 [00:00<00:00, 35.21it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.80it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.36it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.17it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.48it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.90it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.42it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.76it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.03it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.44it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.34it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.22it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.84it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.75it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.09it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.09it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.35it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.20it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.77it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.98it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.32it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.73it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.72it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.90it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.65it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.73it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.62it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.77it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.15it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.50it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.60it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.17it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.25it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.75it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.10it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.51it/s]
# 100%|██████████| 16/16 [00:00<00:00, 31.76it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.79it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.40it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.75it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.26it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.83it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.23it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.91it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.44it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.84it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.75it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.73it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.59it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.60it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.70it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.67it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.78it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.96it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.27it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.42it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.39it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.27it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.47it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.72it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.31it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.39it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.67it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.15it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.35it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.96it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.72it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.77it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.99it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.38it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.12it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.45it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.71it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.78it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.70it/s]
# 100%|██████████| 16/16 [00:00<00:00, 31.90it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.91it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.27it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.68it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.49it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.01it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.49it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.79it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.29it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.92it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.14it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.19it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.25it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.54it/s]
# 100%|██████████| 16/16 [00:00<00:00, 30.15it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.62it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.03it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.26it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.46it/s]
# 100%|██████████| 16/16 [00:00<00:00, 31.18it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.83it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.74it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.54it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.24it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.37it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.07it/s]
# 100%|██████████| 16/16 [00:00<00:00, 30.56it/s]
# 100%|██████████| 16/16 [00:00<00:00, 31.10it/s]
# 100%|██████████| 16/16 [00:00<00:00, 31.73it/s]
# 100%|██████████| 16/16 [00:00<00:00, 30.79it/s]
# 100%|██████████| 16/16 [00:00<00:00, 30.99it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.25it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.11it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.98it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.76it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.30it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.98it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.80it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.77it/s]
# 100%|██████████| 16/16 [00:00<00:00, 31.81it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.79it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.87it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.79it/s]
# 100%|██████████| 16/16 [00:00<00:00, 33.30it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.92it/s]

# %%
print(len(pred_train))
print(pred_train[0].shape)
print(pred_train[0].dtype)
# Out:
# 20
# (7, 776, 456)
# float64

# %% [markdown]
# ## Denormalize the predictions

# %%
pred_train_denormalized=copy.deepcopy(pred_train)
for i in range(len(pred_train)):
    pred_train_denormalized[i] = pred_train[i]*std + mean

# %%
slice=6
vmin=np.min(input_train_chopped[12][slice, ...])
vmax=np.max(input_train_chopped[12][slice, ...])

# Let's look at the results.
plt.figure(figsize=(40,20))
plt.subplot(1,3,1)
plt.imshow(input_train_chopped[12][slice, ...], vmin=vmin, vmax=vmax)
plt.title('Input');

plt.subplot(1,3,2)
plt.imshow(pred_train_denormalized[12][slice, ...], vmin=vmin, vmax=vmax)
plt.title('Prediction');

plt.subplot(1,3,3)
plt.imshow(imgsY[12][slice, 60:-60, 60:-60], vmin=vmin, vmax=vmax)
plt.title('Target');

# %% [markdown]
# ## A brief look at how the intensity values have changed after training !

# %%
print(np.min(pred_train_denormalized[6][6, ...]))
print(np.max(pred_train_denormalized[6][6, ...]))
print(np.min(input_train_chopped[6][6, ...]))
print(np.max(input_train_chopped[6][6, ...]))
# Out:
# 99.82552355762644
# 275.2363970415697
# 69.0
# 211.0

# %% [markdown]
# ## Reconstitute the images

# %%
quality
# Out:
# 'Q1/'

# %%
for i in range(10):
    fileindex=390+i
    print(str(fileindex))
    imwrite("/home/lalit/Desktop/04_Data/KellerLabData/04_Denoised/01Sep2019/CM02/"+quality+str(fileindex)+".tif",np.array(pred_train_denormalized[i], dtype='float32'))
# Out:
# 390
# 391
# 392
# 393
# 394
# 395
# 396
# 397
# 398
# 399

# %%
for i in range(10, 20):
    fileindex=390+i-10
    print(str(fileindex))
    imwrite("/home/lalit/Desktop/04_Data/KellerLabData/04_Denoised/01Sep2019/CM03/"+quality+str(fileindex)+".tif",np.array(pred_train_denormalized[i], dtype='float32'))
# Out:
# 390
# 391
# 392
# 393
# 394
# 395
# 396
# 397
# 398
# 399
